# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
u='https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.network_type%255B%255D%3D5G&param=84356&otracker=clp_banner_1_5.bannerX3.BANNER_mobile-phones-store_CY13OQQ2P829&fm=neo%2Fmerchandising&iid=M_13512795-e5e0-467e-a69c-ceaff6fa78d9_5.CY13OQQ2P829&ppt=clp&ppn=mobile-phones-store&ssid=abjiv6yl1c0000001673580222833'

# %%
r=requests.get(u)
w=r.content
b=bs(w,'html.parser')

# %%
b.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim1.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <meta content="noodp" name="robots"/>\n  <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>\n  <link href="/ap
# ...

# %%
con=b.findAll('a',{'class':'_1fQZEK'})

# %%
mobile=[]
for i in con:
    model=i.contents[1].findAll('div',{'class':'_4rR01T'})[0].text
    price=i.contents[1].findAll('div',{'class':'_30jeq3 _1_WHN1'})[0].text
    mob=[model,price]
    mobile.append(mob)

# %%
f= open('mobile.csv', 'w',encoding="utf-8")
csv_writer = csv.writer(f)
for i in mobile:
    csv_writer.writerow(i)
f.close()
